# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os  
from datetime import datetime
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.tsa.stattools import acf
from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.tsa.stattools import pacf
from statsmodels.tsa.arima.model import ARIMA
# %matplotlib inline

# %% [markdown]
# ***SEABORN***

# %%
import seaborn as sns
sns.set_theme()
sns.set(rc={'figure.figsize':(11.7,8.27)})

# %% [markdown]
# ***PLOTLY***

# %%
import plotly
plotly.offline.init_notebook_mode(connected=True)
from plotly import graph_objects as go
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# **READ ALL THE CSV**
#
# reads all the CSV files in the path and returns a dictionary. ignore_list contains the files to be ignored

# %%
def identify_splits(df):
    split_list=[(0,df.loc[0],1)]
    for j,i in df.iterrows():
        if(i["Prev Close"]>1.25*i["Open"]):
            split_list.append((j,i,i["Prev Close"]/i["Open"]))
    return split_list

def factor_list(df):
    factor=[1 for i in range(df.size)]
    split_list=identify_splits(df)
    for i in split_list[1:]:
        for j in range(i[0],df.size):
            factor[j]*=i[2]
    return factor
            

def readallCSV(path,ignore_list=[]):
    allCSV={}
    for i in os.listdir(path):
        if i not in ignore_list:
            df=pd.read_csv(path+i)
            df['Date'] = pd.to_datetime(df['Date'], format='%Y-%m-%d')
            df.set_index(["Date"])
            fact_list=factor_list(df)
#             print(i,df.size,len(fact_list))
            df["Split Factor"]=pd.Series(fact_list)
            allCSV[i[0:-4]]=df        
    print(allCSV.keys())
    return allCSV

# %%
allCSV=readallCSV('./Small_Data/',['stock_metadata.csv','NIFTY50_all.csv'])
# Out:
# dict_keys(['WIPRO', 'GRASIM', 'BAJAJ-AUTO', 'ULTRACEMCO', 'NTPC', 'IOC', 'UPL', 'HDFCBANK', 'KOTAKBANK', 'BPCL', 'ICICIBANK', 'POWERGRID', 'HINDUNILVR', 'LT', 'RELIANCE', 'INFY', 'HINDALCO', 'JSWSTEEL', 'MM', 'HCLTECH', 'HEROMOTOCO', 'GAIL', 'SBIN', 'TECHM', 'BAJFINANCE', 'MARUTI', 'VEDL', 'BAJAJFINSV', 'TITAN', 'ITC', 'DRREDDY', 'CIPLA', 'TATASTEEL', 'ADANIPORTS', 'TATAMOTORS', 'INFRATEL', 'BRITANNIA', 'HDFC', 'ASIANPAINT', 'EICHERMOT', 'INDUSINDBK', 'AXISBANK', 'ONGC', 'SHREECEM', 'TCS', 'ZEEL', 'NESTLEIND', 'SUNPHARMA', 'BHARTIARTL', 'COALINDIA'])

# %% [markdown]
# **Print Number of NAN values in each column for all DFS**

# %%
for df in allCSV:
    print(df)
    print(allCSV[df].shape)
    for i in allCSV[df].columns:
        print(i,allCSV[df][i].isnull().sum(),sep=' = ')
    print("\n\n\n")
# Out:
# WIPRO
# (5141, 16)
# Date = 0
# Symbol = 0
# Series = 0
# Prev Close = 0
# Open = 0
# High = 0
# Low = 0
# Last = 0
# Close = 0
# VWAP = 0
# Volume = 0
# Turnover = 0
# Trades = 2850
# Deliverable Volume = 509
# %Deliverble = 509
# Split Factor = 0
#
#
#
#
# GRASIM
# (5141, 16)
# Date = 0
# Symbol = 0
# Series = 0
# Prev Close = 0
# Open = 0
# High = 0
# Low = 0
# Last = 0
# Close = 0
# VWAP = 0
# Volume = 0
# Turnover = 0
# Trades = 2850
# Deliverable Volume = 509
# %Deliverble = 509
# Split Factor = 0
#
#
#
#
# BAJAJ-AUTO
# (3037, 16)
# Date = 0
# Symbol = 0
# Series = 0
# Prev Close = 0
# Open = 0
# High = 0
# Low = 0
# Last = 0
# Close = 0
# VWAP = 0
# Volume = 0
# Turnover = 0
# Trades = 746
# Deliverable Volume = 0
# %Deliverble = 0
# Split Factor = 0
#
#
#
#
# ULTRACEMCO
# (3975, 16)
# Date = 0
# Symbol = 0
# Series = 0
# Prev Close = 0
# Open = 0
# High = 0
# Low = 0
# Last = 0
# Close = 0
# VWAP = 0
# Volume = 0
# Turnover = 0
# Trades = 1684
# Deliverable Volume = 0
# %Deliverble = 0
# Split Factor = 0
#
#
#
#
# NTPC
# (3923, 16)
# Date = 0
# Symbol = 0
# Series = 0
# Prev Close = 0
# Open = 0
# High = 0
# Low = 0
# Last = 0
# Close = 0
# VWAP = 0
# Volume = 0
# Turnover = 0
# Trades = 1632
# Deliverable Volume = 0
# %Deliverble = 0
# Split Factor = 0
#
#
#
#
# IOC
# (5141, 16)
# Date = 0
# Symbol = 0
# Series = 0
# Prev Close = 0
# Open = 0
# High = 0
# Low = 0
# Last = 0
# Close = 0
# VWAP = 0
# Volume = 0
# Turnover = 0
# Trades = 2850
# Deliverable Volume = 509
# %Deliverble = 509
# Split Factor = 0
#
#
#
#
# UPL
# (4122, 16)
# Date = 0
# Symbol = 0
# Series = 0
# Prev Close = 0
# Open = 0
# High = 0
# Low = 0
# Last = 0
# Close = 0
# VWAP = 0
# Volume = 0
# Turnover = 0
# Trades = 1831
# Deliverable Volume = 6
# %Deliverble = 6
# Split Factor = 0
#
#
#
#
# HDFCBANK
# (5141, 16)
# Date = 0
# Symbol = 0
# Series = 0
# Prev Close = 0
# Open = 0
# High = 0
# Low = 0
# Last = 0
# Close = 0
# VWAP = 0
# Volume = 0
# Turnover = 0
# Trades = 2850
# Deliverable Volume = 509
# %Deliverble = 509
# Split Factor = 0
#
#
#
#
# KOTAKBANK
# (4820, 16)
# Date = 0
# Symbol = 0
# Series = 0
# Prev Close = 0
# Open = 0
# High = 0
# Low = 0
# Last = 0
# Close = 0
# VWAP = 0
# Volume = 0
# Turnover = 0
# Trades = 2529
# Deliverable Volume = 196
# %Deliverble = 196
# Split Factor = 0
#
#
#
#
# BPCL
# (5141, 16)
# Date = 0
# Symbol = 0
# Series = 0
# Prev Close = 0
# Open = 0
# High = 0
# Low = 0
# Last = 0
# Close = 0
# VWAP = 0
# Volume = 0
# Turnover = 0
# Trades = 2850
# Deliverable Volume = 509
# %Deliverble = 509
# Split Factor = 0
#
#
#
#
# ICICIBANK
# (5141, 16)
# Date = 0
# Symbol = 0
# Series = 0
# Prev Close = 0
# Open = 0
# High = 0
# Low = 0
# Last = 0
# Close = 0
# VWAP = 0
# Volume = 0
# Turnover = 0
# Trades = 2850
# Deliverable Volume = 517
# %Deliverble = 517
# Split Factor = 0
#
#
#
#
# POWERGRID
# (3194, 16)
# Date = 0
# Symbol = 0
# Series = 0
# Prev Close = 0
# Open = 0
# High = 0
# Low = 0
# Last = 0
# Close = 0
# VWAP = 0
# Volume = 0
# Turnover = 0
# Trades = 903
# Deliverable Volume = 0
# %Deliverble = 0
# Split Factor = 0
#
#
#
#
# HINDUNILVR
# (5141, 16)
# Date = 0
# Symbol = 0
# Series = 0
# Prev Close = 0
# Open = 0
# High = 0
# Low = 0
# Last = 0
# Close = 0
# VWAP = 0
# Volume = 0
# Turnover = 0
# Trades = 2850
# Deliverable Volume = 515
# %Deliverble = 515
# Split Factor = 0
#
#
#
#
# LT
# (4019, 16)
# Date = 0
# Symbol = 0
# Series = 0
# Prev Close = 0
# Open = 0
# High = 0
# Low = 0
# Last = 0
# Close = 0
# VWAP = 0
# Volume = 0
# Turnover = 0
# Trades = 1728
# Deliverable Volume = 0
# %Deliverble = 0
# Split Factor = 0
#
#
#
#
# RELIANCE
# (5141, 16)
# Date = 0
# Symbol = 0
# Series = 0
# Prev Close = 0
# Open = 0
# High = 0
# Low = 0
# Last = 0
# Close = 0
# VWAP = 0
# Volume = 0
# Turnover = 0
# Trades = 2850
# Deliverable Volume = 514
# %Deliverble = 514
# Split Factor = 0
#
#
#
#
# INFY
# (5141, 16)
# Date = 0
# Symbol = 0
# Series = 0
# Prev Close = 0
# Open = 0
# High = 0
# Low = 0
# Last = 0
# Close = 0
# VWAP = 0
# Volume = 0
# Turnover = 0
# Trades = 2850
# Deliverable Volume = 509
# %Deliverble = 509
# Split Factor = 0
#
#
#
#
# HINDALCO
# (5141, 16)
# Date = 0
# Symbol = 0
# Series = 0
# Prev Close = 0
# Open = 0
# High = 0
# Low = 0
# Last = 0
# Close = 0
# VWAP = 0
# Volume = 0
# Turnover = 0
# Trades = 2850
# Deliverable Volume = 525
# %Deliverble = 525
# Split Factor = 0
#
#
#
#
# JSWSTEEL
# (3829, 16)
# Date = 0
# Symbol = 0
# Series = 0
# Prev Close = 0
# Open = 0
# High = 0
# Low = 0
# Last = 0
# Close = 0
# VWAP = 0
# Volume = 0
# Turnover = 0
# Trades = 1538
# Deliverable Volume = 0
# %Deliverble = 0
# Split Factor = 0
#
#
#
#
# MM
# (5141, 16)
# Date = 0
# Symbol = 0
# Series = 0
# Prev Close = 0
# Open = 0
# High = 0
# Low = 0
# Last = 0
# Close = 0
# VWAP = 0
# Volume = 0
# Turnover = 0
# Trades = 2850
# Deliverable Volume = 509
# %Deliverble = 509
# Split Factor = 0
#
#
#
#
# HCLTECH
# (5135, 16)
# Date = 0
# Symbol = 0
# Series = 0
# Prev Close = 0
# Open = 0
# High = 0
# Low = 0
# Last = 0
# Close = 0
# VWAP = 0
# Volume = 0
# Turnover = 0
# Trades = 2844
# Deliverable Volume = 503
# %Deliverble = 503
# Split Factor = 0
#
#
#
#
# HEROMOTOCO
# (5141, 16)
# Date = 0
# Symbol = 0
# Series = 0
# Prev Close = 0
# Open = 0
# High = 0
# Low = 0
# Last = 0
# Close = 0
# VWAP = 0
# Volume = 0
# Turnover = 0
# Trades = 2850
# Deliverable Volume = 509
# %Deliverble = 509
# Split Factor = 0
#
#
#
#
# GAIL
# (4820, 16)
# Date = 0
# Symbol = 0
# Series = 0
# Prev Close = 0
# Open = 0
# High = 0
# Low = 0
# Last = 0
# Close = 0
# VWAP = 0
# Volume = 0
# Turnover = 0
# Trades = 2529
# Deliverable Volume = 188
# %Deliverble = 188
# Split Factor = 0
#
#
#
#
# SBIN
# (5141, 16)
# Date = 0
# Symbol = 0
# Series = 0
# Prev Close = 0
# Open = 0
# High = 0
# Low = 0
# Last = 0
# Close = 0
# VWAP = 0
# Volume = 0
# Turnover = 0
# Trades = 2850
# Deliverable Volume = 514
# %Deliverble = 514
# Split Factor = 0
#
#
#
#
# TECHM
# (3470, 16)
# Date = 0
# Symbol = 0
# Series = 0
# Prev Close = 0
# Open = 0
# High = 0
# Low = 0
# Last = 0
# Close = 0
# VWAP = 0
# Volume = 0
# Turnover = 0
# Trades = 1179
# Deliverable Volume = 0
# %Deliverble = 0
# Split Factor = 0
#
#
#
#
# BAJFINANCE
# (5070, 16)
# Date = 0
# Symbol = 0
# Series = 0
# Prev Close = 0
# Open = 0
# High = 0
# Low = 0
# Last = 0
# Close = 0
# VWAP = 0
# Volume = 0
# Turnover = 0
# Trades = 2779
# Deliverable Volume = 446
# %Deliverble = 446
# Split Factor = 0
#
#
#
#
# MARUTI
# (4262, 16)
# Date = 0
# Symbol = 0
# Series = 0
# Prev Close = 0
# Open = 0
# High = 0
# Low = 0
# Last = 0
# Close = 0
# VWAP = 0
# Volume = 0
# Turnover = 0
# Trades = 1971
# Deliverable Volume = 1
# %Deliverble = 1
# Split Factor = 0
#
#
#
#
# VEDL
# (5140, 16)
# Date = 0
# Symbol = 0
# Series = 0
# Prev Close = 0
# Open = 0
# High = 0
# Low = 0
# Last = 0
# Close = 0
# VWAP = 0
# Volume = 0
# Turnover = 0
# Trades = 2849
# Deliverable Volume = 513
# %Deliverble = 513
# Split Factor = 0
#
#
#
#
# BAJAJFINSV
# (3036, 16)
# Date = 0
# Symbol = 0
# Series = 0
# Prev Close = 0
# Open = 0
# High = 0
# Low = 0
# Last = 0
# Close = 0
# VWAP = 0
# Volume = 0
# Turnover = 0
# Trades = 745
# Deliverable Volume = 0
# %Deliverble = 0
# Split Factor = 0
#
#
#
#
# TITAN
# (5141, 16)
# Date = 0
# Symbol = 0
# Series = 0
# Prev Close = 0
# Open = 0
# High = 0
# Low = 0
# Last = 0
# Close = 0
# VWAP = 0
# Volume = 0
# Turnover = 0
# Trades = 2850
# Deliverable Volume = 514
# %Deliverble = 514
# Split Factor = 0
#
#
#
#
# ITC
# (5141, 16)
# Date = 0
# Symbol = 0
# Series = 0
# Prev Close = 0
# Open = 0
# High = 0
# Low = 0
# Last = 0
# Close = 0
# VWAP = 0
# Volume = 0
# Turnover = 0
# Trades = 2850
# Deliverable Volume = 514
# %Deliverble = 514
# Split Factor = 0
#
#
#
#
# DRREDDY
# (5141, 16)
# Date = 0
# Symbol = 0
# Series = 0
# Prev Close = 0
# Open = 0
# High = 0
# Low = 0
# Last = 0
# Close = 0
# VWAP = 0
# Volume = 0
# Turnover = 0
# Trades = 2850
# Deliverable Volume = 509
# %Deliverble = 509
# Split Factor = 0
#
#
#
#
# CIPLA
# (5141, 16)
# Date = 0
# Symbol = 0
# Series = 0
# Prev Close = 0
# Open = 0
# High = 0
# Low = 0
# Last = 0
# Close = 0
# VWAP = 0
# Volume = 0
# Turnover = 0
# Trades = 2850
# Deliverable Volume = 514
# %Deliverble = 514
# Split Factor = 0
#
#
#
#
# TATASTEEL
# (5141, 16)
# Date = 0
# Symbol = 0
# Series = 0
# Prev Close = 0
# Open = 0
# High = 0
# Low = 0
# Last = 0
# Close = 0
# VWAP = 0
# Volume = 0
# Turnover = 0
# Trades = 2850
# Deliverable Volume = 514
# %Deliverble = 514
# Split Factor = 0
#
#
#
#
# ADANIPORTS
# (3157, 16)
# Date = 0
# Symbol = 0
# Series = 0
# Prev Close = 0
# Open = 0
# High = 0
# Low = 0
# Last = 0
# Close = 0
# VWAP = 0
# Volume = 0
# Turnover = 0
# Trades = 866
# Deliverable Volume = 0
# %Deliverble = 0
# Split Factor = 0
#
#
#
#
# TATAMOTORS
# (5141, 16)
# Date = 0
# Symbol = 0
# Series = 0
# Prev Close = 0
# Open = 0
# High = 0
# Low = 0
# Last = 0
# Close = 0
# VWAP = 0
# Volume = 0
# Turnover = 0
# Trades = 2850
# Deliverable Volume = 514
# %Deliverble = 514
# Split Factor = 0
#
#
#
#
# INFRATEL
# (1897, 16)
# Date = 0
# Symbol = 0
# Series = 0
# Prev Close = 0
# Open = 0
# High = 0
# Low = 0
# Last = 0
# Close = 0
# VWAP = 0
# Volume = 0
# Turnover = 0
# Trades = 0
# Deliverable Volume = 0
# %Deliverble = 0
# Split Factor = 0
#
#
#
#
# BRITANNIA
# (5140, 16)
# Date = 0
# Symbol = 0
# Series = 0
# Prev Close = 0
# Open = 0
# High = 0
# Low = 0
# Last = 0
# Close = 0
# VWAP = 0
# Volume = 0
# Turnover = 0
# Trades = 2849
# Deliverable Volume = 509
# %Deliverble = 509
# Split Factor = 0
#
#
#
#
# HDFC
# (5141, 16)
# Date = 0
# Symbol = 0
# Series = 0
# Prev Close = 0
# Open = 0
# High = 0
# Low = 0
# Last = 0
# Close = 0
# VWAP = 0
# Volume = 0
# Turnover = 0
# Trades = 2850
# Deliverable Volume = 509
# %Deliverble = 509
# Split Factor = 0
#
#
#
#
# ASIANPAINT
# (5141, 16)
# Date = 0
# Symbol = 0
# Series = 0
# Prev Close = 0
# Open = 0
# High = 0
# Low = 0
# Last = 0
# Close = 0
# VWAP = 0
# Volume = 0
# Turnover = 0
# Trades = 2850
# Deliverable Volume = 509
# %Deliverble = 509
# Split Factor = 0
#
#
#
#
# EICHERMOT
# (5136, 16)
# Date = 0
# Symbol = 0
# Series = 0
# Prev Close = 0
# Open = 0
# High = 0
# Low = 0
# Last = 0
# Close = 0
# VWAP = 0
# Volume = 0
# Turnover = 0
# Trades = 2845
# Deliverable Volume = 504
# %Deliverble = 504
# Split Factor = 0
#
#
#
#
# INDUSINDBK
# (4820, 16)
# Date = 0
# Symbol = 0
# Series = 0
# Prev Close = 0
# Open = 0
# High = 0
# Low = 0
# Last = 0
# Close = 0
# VWAP = 0
# Volume = 0
# Turnover = 0
# Trades = 2529
# Deliverable Volume = 188
# %Deliverble = 188
# Split Factor = 0
#
#
#
#
# AXISBANK
# (5141, 16)
# Date = 0
# Symbol = 0
# Series = 0
# Prev Close = 0
# Open = 0
# High = 0
# Low = 0
# Last = 0
# Close = 0
# VWAP = 0
# Volume = 0
# Turnover = 0
# Trades = 2850
# Deliverable Volume = 509
# %Deliverble = 509
# Split Factor = 0
#
#
#
#
# ONGC
# (5141, 16)
# Date = 0
# Symbol = 0
# Series = 0
# Prev Close = 0
# Open = 0
# High = 0
# Low = 0
# Last = 0
# Close = 0
# VWAP = 0
# Volume = 0
# Turnover = 0
# Trades = 2850
# Deliverable Volume = 509
# %Deliverble = 509
# Split Factor = 0
#
#
#
#
# SHREECEM
# (4820, 16)
# Date = 0
# Symbol = 0
# Series = 0
# Prev Close = 0
# Open = 0
# High = 0
# Low = 0
# Last = 0
# Close = 0
# VWAP = 0
# Volume = 0
# Turnover = 0
# Trades = 2529
# Deliverable Volume = 188
# %Deliverble = 188
# Split Factor = 0
#
#
#
#
# TCS
# (3974, 16)
# Date = 0
# Symbol = 0
# Series = 0
# Prev Close = 0
# Open = 0
# High = 0
# Low = 0
# Last = 0
# Close = 0
# VWAP = 0
# Volume = 0
# Turnover = 0
# Trades = 1683
# Deliverable Volume = 0
# %Deliverble = 0
# Split Factor = 0
#
#
#
#
# ZEEL
# (5141, 16)
# Date = 0
# Symbol = 0
# Series = 0
# Prev Close = 0
# Open = 0
# High = 0
# Low = 0
# Last = 0
# Close = 0
# VWAP = 0
# Volume = 0
# Turnover = 0
# Trades = 2850
# Deliverable Volume = 519
# %Deliverble = 519
# Split Factor = 0
#
#
#
#
# NESTLEIND
# (2641, 16)
# Date = 0
# Symbol = 0
# Series = 0
# Prev Close = 0
# Open = 0
# High = 0
# Low = 0
# Last = 0
# Close = 0
# VWAP = 0
# Volume = 0
# Turnover = 0
# Trades = 350
# Deliverable Volume = 0
# %Deliverble = 0
# Split Factor = 0
#
#
#
#
# SUNPHARMA
# (5141, 16)
# Date = 0
# Symbol = 0
# Series = 0
# Prev Close = 0
# Open = 0
# High = 0
# Low = 0
# Last = 0
# Close = 0
# VWAP = 0
# Volume = 0
# Turnover = 0
# Trades = 2850
# Deliverable Volume = 528
# %Deliverble = 528
# Split Factor = 0
#
#
#
#
# BHARTIARTL
# (4609, 16)
# Date = 0
# Symbol = 0
# Series = 0
# Prev Close = 0
# Open = 0
# High = 0
# Low = 0
# Last = 0
# Close = 0
# VWAP = 0
# Volume = 0
# Turnover = 0
# Trades = 2318
# Deliverable Volume = 16
# %Deliverble = 16
# Split Factor = 0
#
#
#
#
# COALINDIA
# (2433, 16)
# Date = 0
# Symbol = 0
# Series = 0
# Prev Close = 0
# Open = 0
# High = 0
# Low = 0
# Last = 0
# Close = 0
# VWAP = 0
# Volume = 0
# Turnover = 0
# Trades = 142
# Deliverable Volume = 0
# %Deliverble = 0
# Split Factor = 0

# %% [markdown]
# * **Data** - Represents the Data
# * **Symbol** - Represents the symbol which represents the entity
# * **Series** - EQ refers to Equity
# * **Prev Close** - Previous Working Day Close Price
# * **Open** - Open price of the stock on that working day
# * **Close** - Close price of the stock on that working day
# * **High** - Highest price of the stock on that working day
# * **Low** - Lowest price of the stock on that working day
# * **Close** - Closing price of stock on that working day
# * **VWAP** - The volume weighted average price is a trading benchmark used by traders that gives the average price a security has traded at throughout the day, based on both volume and price.
# * **Volume** - Volume is the number of shares of a security traded during a given period of time
# * **Turnover** - Share turnover is a measure of stock liquidity calculated by dividing the total number of shares traded over a period by the average number of shares outstanding for the period. *The higher the share turnover, the more liquid company shares are.*
# * **Deliverable Volume**  - The total number of unique stocks transacted on a given day. This denotes *liquidity*
# * **Deliverable Percentage** - The percentage of the total shares which were transacted on a given day
# * **Split Factor** - Shares that grow in value over time are split into multiple smaller shares in order to increase flexibility and liquidity in the process of trade. This split shall result in false dips when predicting a model and hence must be neutralised

# %%
allCSV["HDFC"].head()
# Out:
#         Date Symbol Series  Prev Close   Open    High    Low   Last   Close  \
# 0 2000-01-03   HDFC     EQ      271.75  293.5  293.50  293.5  293.5  293.50
# 1 2000-01-04   HDFC     EQ      293.50  317.0  317.00  297.0  304.0  304.05
# 2 2000-01-05   HDFC     EQ      304.05  290.0  303.90  285.0  295.0  292.80
# 3 2000-01-06   HDFC     EQ      292.80  301.0  314.00  295.0  296.0  296.45
# 4 2000-01-07   HDFC     EQ      296.45  290.0  296.35  281.0  287.1  286.55
#
#      VWAP  Volume      Turnover  Trades  Deliverable Volume  %Deliverble  \
# 0  293.50   22744  6.675364e+11     NaN                 NaN          NaN
# 1  303.62  255251  7.749972e+12     NaN                 NaN          NaN
# 2  294.53  269087  7.925368e+12     NaN                 NaN          NaN
# 3  300.14  305916  9.181669e+12     NaN                 NaN          NaN
# 4  288.80  197039  5.690480e+12     NaN                 NaN          NaN
#
#    Split Factor
# 0           1.0
# 1           1.0
# 2           1.0
# 3           1.0
# 4           1.0

# %% [markdown]
# **CANDLE PLOT TIME SERIES**
#
# given a df, plots the time-series

# %%
def candle_plot(df):
    fig = go.Figure(data=[go.Candlestick(x=df['Date'],
                    open=df['Open'], high=df['High'],
                    low=df['Low'], close=df['Close'])
                         ])
    fig.update_layout(xaxis_rangeslider_visible=True)
    fig.show()

# %%
hdfc = allCSV['HDFC']
candle_plot(allCSV['HDFC'])
# Out:
# <div>                            <div id="fed8c0f9-499f-464c-992e-f1d662eba920" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fed8c0f9-499f-464c-992e-f1d662eba920")) {                    Plotly.newPlot(                        "fed8c0f9-499f-464c-992e-f1d662eba920",                        [{"close": [293.5, 304.05, 292.8, 296.45, 286.55, 287.2, 283.85, 285.6, 283.85, 286.55, 302.2, 305.75, 305.25, 291.35, 299.55, 293.05, 303.15, 316.6, 324.4, 333.5, 350.55, 351.4, 341.9, 357.2, 355.45, 350.5, 329.15, 320.35, 343.65, 359.15, 332.6, 341.6, 339.2, 327.9, 319.15, 305.95, 330.45, 351.7, 379.85, 409.7, 401.7, 433.85, 468.6, 473.05, 443.5, 412.2, 416.7, 399.6, 397.55, 381.6, 396.65, 400.5, 398.2, 406.35, 413.25, 409.85, 416.8, 417.4, 412.7, 380.3, 363.85, 393.0, 424.45, 458.45, 469.8, 459.25, 490.95, 477.7, 464.3, 453.25, 448.7, 433.1, 445.4, 459.35, 475.1, 448.05, 456.9, 460.65, 460.15, 472.35, 479.35, 460.85, 455.75, 449.0, 437.55, 424.95, 441.75, 448.65, 461.05, 460.4, 471.75, 461.35, 465.45, 477.65, 486.15, 501.9, 486.4, 473.0, 483.3, 541.3, 543.65, 478.45, 496.35, 525.35, 544.7, 530.7, 513.2, 515.25, 509.35, 503.6, 495.35, 488.2, 484.85, 499.85, 504.1, 509.2, 525.1, 525.35, 536.25, 541.15, 558.2, 551.55, 548.15, 551.65, 548.7, 480.0, 484.65, 511.25, 499.9, 489.85, 481.2, 490.55, 487.65, 478.55, 480.95, 475.55, 475.3, 511.65, 509.25, 501.0, 498.4, 499.75, 500.3, 500.05, 505.9, 499.3, 491.75, 489.15, 503.15, 502.75, 505.55, 493.55, 496.05, 504.95, 503.15, 522.8, 513.0, 501.1, 490.4, 482.9, 489.6, 495.35, 500.5, 500.7, 505.0, 520.15, 524.05, 528.25, 544.6, 539.95, 534.3, 532.2, 529.45, 520.65, 506.0, 513.55, 507.5, 499.55, 502.05, 500.0, 499.7, 481.0, 474.95, 445.15, 426.55, 441.05, 437.85, 433.9, 439.0, 439.0, 449.45, 449.25, 455.95, 448.6, 449.65, 450.0, 450.85, 458.8, 458.75, 477.4, 469.75, 464.65, 457.35, 462.2, 461.3, 464.1, 471.45, 470.25, 480.0, 489.85, 488.5, 482.9, 485.6, 489.0, 488.2, 496.85, 508.05, 496.8, 500.4, 494.65, 489.2, 477.35, 477.25, 474.15, 485.5, 509.4, 525.1, 528.0, 524.65, 529.2, 519.5, 523.4, 522.55, 530.75, 535.3, 546.7, 555.6, 561.55, 555.35, 553.3, 560.45, 555.3, 556.5, 554.75, 545.05, 549.3, 542.75, 536.6, 538.7, 541.8, 538.25, 542.15, 552.15, 550.6, 583.3, 589.35, 595.6, 572.45, 551.15, 547.85, 536.35, 529.35, 531.55, 529.9, 515.0, 505.5, 495.5, 513.85, 545.25, 582.2, 558.9, 554.85, 555.15, 573.85, 558.65, 554.55, 558.45, 573.25, 593.05, 578.75, 574.75, 571.1, 574.35, 567.4, 577.7, 568.6, 567.9, 562.8, 555.6, 569.7, 591.3, 593.5, 598.5, 556.1, 526.15, 544.05, 540.8, 540.35, 545.05, 546.0, 594.0, 572.7, 571.85, 569.45, 556.8, 568.8, 586.4, 586.2, 578.85, 586.7, 574.25, 567.2, 546.4, 568.4, 578.35, 560.45, 560.45, 552.6, 550.2, 551.35, 555.25, 585.0, 594.95, 576.95, 571.2, 569.55, 583.5, 589.4, 596.8, 587.2, 581.2, 574.0, 589.55, 592.95, 604.45, 611.75, 608.85, 591.05, 591.05, 588.85, 590.1, 594.55, 609.15, 671.45, 660.1, 651.25, 641.1, 649.95, 660.1, 660.15, 664.65, 674.0, 672.15, 663.1, 665.5, 666.35, 667.65, 652.1, 650.35, 662.05, 670.0, 668.25, 652.95, 649.45, 653.8, 657.85, 669.2, 674.4, 666.05, 666.15, 674.8, 695.3, 688.9, 676.95, 690.3, 662.35, 663.6, 669.8, 664.9, 660.0, 652.85, 650.55, 660.15, 651.15, 664.1, 660.85, 659.9, 659.85, 654.5, 633.7, 629.55, 633.25, 640.4, 651.05, 657.45, 653.7, 670.0, 680.75, 673.4, 670.3, 669.85, 662.1, 665.0, 667.1, 678.1, 664.05, 662.9, 662.85, 680.9, 689.0, 702.5, 710.45, 702.25, 677.7, 675.9, 680.1, 697.1, 704.85, 691.8, 689.9, 697.3, 706.85, 710.5, 720.35, 709.35, 668.35, 678.7, 620.75, 620.3, 627.35, 666.6, 645.65, 644.2, 617.9, 674.55, 629.95, 629.95, 623.45, 653.75, 649.25, 699.3, 673.0, 670.15, 681.85, 650.45, 669.25, 657.7, 652.65, 664.55, 663.7, 650.35, 640.65, 645.55, 654.45, 678.55, 677.95, 678.2, 694.4, 698.15, 700. ...

# %%
allCSV['HDFC'].describe()
# Out:
#         Prev Close         Open         High          Low         Last  \
# count  5141.000000  5141.000000  5141.000000  5141.000000  5141.000000
# mean   1250.235295  1250.866553  1270.373556  1230.175170  1250.370064
# std     692.794341   692.954979   704.615342   680.761221   692.541757
# min     271.750000   284.000000   290.500000   273.250000   282.850000
# 25%     665.800000   665.450000   674.700000   657.400000   665.850000
# 50%    1099.600000  1100.000000  1117.000000  1077.000000  1098.150000
# 75%    1762.000000  1765.700000  1792.700000  1740.000000  1762.000000
# max    3180.150000  3148.000000  3262.000000  3100.550000  3178.000000
#
#              Close         VWAP        Volume      Turnover         Trades  \
# count  5141.000000  5141.000000  5.141000e+03  5.141000e+03    2291.000000
# mean   1250.538903  1250.162379  1.764469e+06  2.373866e+14   97687.354867
# std     692.707454   692.428824  2.980988e+06  3.291024e+14   55197.587466
# min     283.850000   283.600000  2.919000e+03  1.834686e+11     973.000000
# 25%     666.050000   665.370000  2.896580e+05  2.275939e+13   59893.500000
# 50%    1099.750000  1099.570000  1.239746e+06  1.611455e+14   86901.000000
# 75%    1762.250000  1762.550000  2.623207e+06  3.189503e+14  122501.000000
# max    3180.150000  3166.580000  1.584141e+08  1.043773e+16  454758.000000
#
#        Deliverable Volume  %Deliverble  Split Factor
# count        4.632000e+03  4632.000000   5141.000000
# mean         1.292154e+06     0.657592      5.290673
# std          2.584001e+06     0.127174      3.757939
# min          1.786000e+03     0.119000      1.000000
# 25%          2.560635e+05     0.582775      1.917639
# 50%          9.622980e+05     0.672000      1.917639
# 75%          1.885564e+06     0.744600      9.158856
# max          1.483131e+08     0.989400      9.158856

# %% [markdown]
# **LINE PLOT**
#
# The lineplot function plots the trend of the given field from start_date to end_date for the list of given companies

# %%
def strpdate(s):
    return datetime.strptime(s,'%d-%m-%Y')

def lineplot(field,start_date,end_date,allCSV,dflist=[]):
    for i in dflist:
        if i in allCSV:
            df=allCSV[i]
            rows=df[(df['Date']>=strpdate(start_date)) & (df['Date']<=strpdate(end_date))]
            sns.lineplot(x=rows['Date'],y=map(lambda x,y:x*y,rows[field],rows["Split Factor"]))
    plt.legend(labels=dflist)

# %%
lineplot('Close','28-10-2010','28-10-2015',allCSV,['HDFC','TATAMOTORS','TCS'])

# %%
lineplot('Trades','28-10-2019','28-10-2020',allCSV,['HDFC'])

# %%
lineplot('Volume','28-10-2019','28-10-2020',allCSV,['HDFC'])

# %% [markdown]
# **TODO**
# *The next task we must do is to bridge the falls when the shares split*

# %%
def rollingMeanPlot(df, start_date, end_date, field):
    rolMean = df[field].rolling(window = 12).mean()
    rolStd = df[field].rolling(window = 12).std()
    rows=df[(df['Date']>=strpdate(start_date)) & (df['Date']<=strpdate(end_date))]
    sns.lineplot(x = rows['Date'],y=rows[field])
    sns.lineplot(x = rows['Date'], y = rolMean)
    plt.legend(labels=['Original Data', 'Rolling Mean'])

# %%
rollingMeanPlot(allCSV['HDFC'], '28-10-2010', '28-10-2012', "Close")

# %%
def rollingStdPlot(df, start_date, end_date, field):
    rolStd = df[field].rolling(window = 12).std()
    rows=df[(df['Date']>=strpdate(start_date)) & (df['Date']<=strpdate(end_date))]
    sns.lineplot(x = rows['Date'], y = rolStd)
    plt.legend(labels=['Rolling Standard Deviation'])

# %%
rollingStdPlot(allCSV['HDFC'], '28-10-2010', '28-10-2012', "Close")

# %%
def dfInDateRange(df, start_date, end_date):
    rows=df[(df['Date']>=strpdate(start_date)) & (df['Date']<=strpdate(end_date))]
    return rows

# %%
def compute_q(arr):
    index_arr=[]
    for i in range(len(arr)):
        if (arr[i][0]>0 or arr[i][1]<0):
            index_arr.append(i)
    return index_arr[1:3]

# %%
start_date, end_date = '28-9-2018', '28-10-2020'
company = 'BAJAJ-AUTO'
companyData = allCSV[company]
dateDf = dfInDateRange(companyData, start_date, end_date)
series = dateDf['Close'] * dateDf['Split Factor']
series = np.array(series[1:len(series)])-np.array(series[0:len(series)-1])
plot_acf(series)
plt.show()
print(acf(series,alpha=0.05)[1])
print(compute_q(acf(series,alpha=0.05)[1]))

# %%
def compute_p(arr):
    index_arr=[]
    for i in range(len(arr)):
        if (arr[i][0]>0 or arr[i][1]<0):
            index_arr.append(i)
    return index_arr[1:3]

# %%
start_date, end_date = '28-10-2017', '28-10-2020'
company = 'BAJAJ-AUTO'
companyData = allCSV[company]
series = dateDf['Close'] * dateDf['Split Factor']
series = np.array(series[1:len(series)])-np.array(series[0:len(series)-1])
print(series)
print(pacf(series,alpha=0.05))
p = compute_p(pacf(series,alpha=0.05)[1])
print(p)
plot_pacf(series,alpha=0.05)
plt.show()

# %%
from statsmodels.tsa.stattools import arma_order_select_ic
start_date, end_date = '28-10-2017', '28-10-2020'
company = 'BAJAJ-AUTO'
companyData = allCSV[company]
series = dateDf['Close'] * dateDf['Split Factor']
print(arma_order_select_ic(series, max_ar=4, max_ma=4, ic='bic'))

# %%
def plot_arima(df,start_date,end_date):
#     start_date, end_date = '28-9-2018', '28-10-2020'
#     company = 'HDFC'
#     companyData = allCSV[company]
    X = dfInDateRange(df, start_date, end_date)
    X = X["Close"]
    size = int(0.85 * len(X))
    train, test = X[0:size].reset_index()["Close"], X[size:].reset_index()["Close"]
    history = [x for x in train]
    predictions = []
    
    series = np.array(train[1:len(train)])-np.array(train[0:len(train)-1])
    p = compute_p(pacf(series,alpha=0.05)[1])
    q = compute_q(acf(series,alpha=0.05)[1])
    order = (p,1,q)
    print(p,q)

    for t in range(len(test)):
        model = ARIMA(history, order = order)
        model_fit = model.fit()
        output = model_fit.forecast()
        yhat = output[0]
        predictions.append(yhat)
        obs = test[t]
        history.append(obs)
        print('predicted=%f, expected=%f' % (yhat, obs))

    # test.insert(0,0)
    plt.plot(test)
    plt.plot(predictions, color='red')
    plt.show()

# %%
plot_arima(allCSV['HDFC'],'28-9-2018', '28-10-2020')
# Out:
# [3, 5] [3, 5]
# predicted=1622.962495, expected=1597.300000
# predicted=1598.852504, expected=1516.150000
# predicted=1477.660942, expected=1502.150000
# predicted=1513.187134, expected=1570.400000
# predicted=1608.415246, expected=1623.700000
# predicted=1599.292899, expected=1658.900000
# predicted=1633.682479, expected=1737.700000
# predicted=1738.187871, expected=1813.550000
# predicted=1811.367022, expected=1835.650000
# predicted=1825.501427, expected=1764.300000
# predicted=1755.798954, expected=1766.600000
# predicted=1775.821588, expected=1760.800000
# predicted=1784.958715, expected=1772.100000
# predicted=1771.723984, expected=1809.300000
# predicted=1798.296640, expected=1787.450000
# predicted=1797.520612, expected=1792.200000
# predicted=1785.051177, expected=1751.650000
# predicted=1755.171671, expected=1821.900000
# predicted=1834.277982, expected=1794.650000
# predicted=1792.243969, expected=1855.950000
# predicted=1846.753182, expected=1835.100000
# predicted=1836.883208, expected=1819.400000
# predicted=1822.376909, expected=1838.100000
# predicted=1832.736438, expected=1797.750000
# predicted=1814.828926, expected=1777.800000
# predicted=1770.346287, expected=1769.350000
# predicted=1770.939812, expected=1741.150000
# predicted=1757.909415, expected=1754.650000
# predicted=1743.132348, expected=1835.150000
# predicted=1838.379898, expected=1889.450000
# predicted=1892.700708, expected=1885.200000
# predicted=1858.581663, expected=1868.700000
# predicted=1865.206180, expected=1886.750000
# predicted=1904.836619, expected=1886.050000
# predicted=1887.500908, expected=1941.850000
# predicted=1936.379324, expected=1886.000000
# predicted=1888.759075, expected=1845.550000
# predicted=1839.610239, expected=1791.600000
# predicted=1801.476455, expected=1789.900000
# predicted=1810.509365, expected=1787.800000
# predicted=1782.419770, expected=1805.850000
# predicted=1803.013241, expected=1806.050000
# predicted=1804.681326, expected=1883.650000
# predicted=1878.380834, expected=1881.050000
# predicted=1881.732913, expected=1875.800000
# predicted=1863.698943, expected=1841.300000
# predicted=1838.813487, expected=1850.750000
# predicted=1867.919289, expected=1897.350000
# predicted=1896.432225, expected=1877.300000
# predicted=1873.249827, expected=1810.650000
# predicted=1801.924901, expected=1781.950000
# predicted=1786.961729, expected=1739.800000
# predicted=1762.391075, expected=1781.100000
# predicted=1777.760232, expected=1776.700000
# predicted=1772.900940, expected=1783.750000
# predicted=1780.339698, expected=1777.700000
# predicted=1768.768030, expected=1798.950000
# predicted=1807.334101, expected=1826.750000
# predicted=1824.796573, expected=1814.200000
# predicted=1806.492088, expected=1804.850000
# predicted=1802.128093, expected=1791.700000
# predicted=1796.258864, expected=1800.550000
# predicted=1805.315356, expected=1820.700000
# predicted=1818.962792, expected=1827.950000
# predicted=1825.562600, expected=1785.150000
# predicted=1780.632400, expected=1804.050000
# predicted=1804.254442, expected=1829.850000
# predicted=1841.684309, expected=1829.600000
# predicted=1824.904754, expected=1816.000000
# predicted=1801.963206, expected=1864.100000
# predicted=1873.344037, expected=1883.250000
# predicted=1888.723959, expected=1832.600000
